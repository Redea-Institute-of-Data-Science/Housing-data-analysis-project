# %% [markdown]
# <p style="text-align:left">
#     <a href="https://rids.ac.ug" target="_blank">
#     <img src="https://rids.ac.ug/wp-content/uploads/2024/02/redea-icon-fin.png" width="75" alt="Redea Logo">
#     </a>
# </p>
#
# <h1 align="left"><font size="10">Project: House Sales in King County, USA </font></h1>

# %% [markdown]
# ## About the Project
# This repository contains data and code to be used for training purposes.
# This dataset contains house sale prices for King County, which includes Seattle and was taken from [Kagle](https://www.kaggle.com/datasets/harlfoxem/housesalesprediction).
#
# NOTE: We have modified the dataset to provide more useful usecase
#
# Please check out the Repo README.md file for more information

# %% [markdown]
# ## Loading the required packages
# This notebook is entirely dedicated to data cleaning and there we shall nly load the packages that we shall use during the data clearning process

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv("filepath/dataset.csv")

# %% [markdown]
# ## Exploring the dataset

# %%
# loooking at the first 10 rows
df.head(10)
# Out:
#     0  7129300520  20141013T000000   221900    3     1  1180    5650  1.1  \
# 0   1  6414100192  20141209T000000   538000  3.0  2.25  2570    7242  2.0
# 1   2  5631500400  20150225T000000   180000  2.0  1.00   770   10000  1.0
# 2   3  2487200875  20141209T000000   604000  4.0  3.00  1960    5000  1.0
# 3   4  1954400510  20150218T000000   510000  3.0  2.00  1680    8080  1.0
# 4   5  7237550310  20140512T000000  1225000  4.0  4.50  5420  101930  1.0
# 5   6  1321400060  20140627T000000   257500  3.0  2.25  1715    6819  2.0
# 6   7  2008000270  20150115T000000   291850  3.0  1.50  1060    9711  1.0
# 7   8  2414600126  20150415T000000   229500  3.0  1.00  1780    7470  1.0
# 8   9  3793500160  20150312T000000   323000  3.0  2.50  1890    6560  2.0
# 9  10  1736800520  20150403T000000   662500  3.0  2.50  3560    9796  1.0
#
#    0.1  ...   7  1180.1   0.3  1955   0.4  98178  47.5112  -122.257  1340  \
# 0    0  ...   7    2170   400  1951  1991  98125  47.7210  -122.319  1690
# ...

# %%
#defining column headers
headers = ['index', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
       'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
       'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
       'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

# %%
# assigning headers to our dataset
df.columns = headers

# %%
# printing the headers
df.columns
# Out:
# Index(['index', 'id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# printing the first 5 rows
df.head(5)
# Out:
#    index          id             date    price  bedrooms  bathrooms  \
# 0      1  6414100192  20141209T000000   538000       3.0       2.25
# 1      2  5631500400  20150225T000000   180000       2.0       1.00
# 2      3  2487200875  20141209T000000   604000       4.0       3.00
# 3      4  1954400510  20150218T000000   510000       3.0       2.00
# 4      5  7237550310  20140512T000000  1225000       4.0       4.50
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         2570      7242     2.0           0  ...      7        2170
# 1          770     10000     1.0           0  ...      6         770
# 2         1960      5000     1.0           0  ...      7        1050
# 3         1680      8080     1.0           0  ...      8        1680
# 4         5420    101930     1.0           0  ...     11        3890
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0            400      1951          1991    98125  47.7210 -122.319
# ...

# %% [markdown]
# From the above lines of code, we have successfully created and assigned headers to our dataset. We shall now go ahead and look at other parameters

# %%
### Structure of the dataset
df.shape
# Out:
# (21613, 22)

# %% [markdown]
# The above output imples that there are 21613 observations and 22 columns (variables/features). Altrnatively we cal also look at the following to achive the same

# %%
# total number of observations
df.shape[0]
# Out:
# 21613

# %%
# alternatively
len(df)
# Out:
# 21613

# %%
### Dropping some irrelevant columns
